# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/processed/dept35_22.csv')

# %%
df.head()
# Out:
#    Sku Number  Year Number  Month Number  Store Number  Total Sales  \
# 0      163320           22             1             1        38.97
# 1      163320           22             1             5        25.98
# 2      163320           22             1             6        38.97
# 3      163320           22             1             7        25.98
# 4      163320           22             1             8        25.98
#
#    Total Units Sold  Total OH Inventory Cost  Total OH Inventory Unit
# 0               3.0                    22.06                      3.0
# 1               2.0                    27.03                      4.0
# 2               3.0                    14.79                      2.0
# 3               2.0                    34.20                      5.0
# 4               2.0                    41.27                      6.0

# %%
plt.figure(figsize=(20, 10))

sns.boxplot(data = df, x = 'Month Number', y = 'Total Units Sold')
# Out:
# <AxesSubplot:xlabel='Month Number', ylabel='Total Units Sold'>

# %% [markdown]
# ### Mad outliers

# %%
plt.figure(figsize=(20, 10))

sns.boxplot(data = df, x = 'Month Number', y = 'Total Sales')
# Out:
# <AxesSubplot:xlabel='Month Number', ylabel='Total Sales'>

# %% [markdown]
# ### Quite literally nearly identical to the above boxplot
